# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # load the data

# %%
# pip install openpyxl
df= pd.read_excel('Canada.xlsx', sheet_name='Canada by Citizenship',
skiprows=20, skipfooter=2)
df.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# 2  3623  4005  5393  4752  4325  3774  4331
# 3     0     0     0     0     0     0     0
# 4     1     0     0     0     0     1     1
#
# [5 rows x 43 columns]

# %% [markdown]
# # preprocessing of data according to need

# %% [markdown]
# the columns that are unnecessary ... removing them from table
# making another column a index column if it has unique value

# %%
print(df.columns.tolist())
# Out:
# ['Type', 'Coverage', 'OdName', 'AREA', 'AreaName', 'REG', 'RegName', 'DEV', 'DevName', 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %% [markdown]
# column renaming according to need

# %%
df.rename({
    'OdName':'country',
    'AreaName':'continent',
    'RegName':'region',
    'DevName':'country_status'
}, axis=1, inplace=True )   #rename checks the index so we need to tell them axis

# %% [markdown]
# check the count of values in a categorical column  and drop if the count is 1

# %%
df.describe(include='object')
# Out:
#               Type    Coverage      country continent        region  \
# count          195         195          195       195           195
# unique           1           2          195         6            22
# top     Immigrants  Foreigners  Afghanistan    Africa  Western Asia
# freq           195         194            1        54            18
#
#             country_status
# count                  195
# unique                   2
# top     Developing regions
# freq                   147

# %%
df['Type'].value_counts()  # count the no. of each unique value in the column
# Out:
# Immigrants    195
# Name: Type, dtype: int64

# %% [markdown]
# drop the columns which are not required

# %%
#if a single column has same values in whole column so it doesn't help in analysis
# so we are removing those columns
cols_to_drop=['Type', 'Coverage', 'AREA','REG','DEV']
df.drop(columns=cols_to_drop, inplace=True)  #column with no useful data are dropped

# %% [markdown]
# setting the index of country names

# %%
df.set_index('country', inplace=True) #set the country as the index column

# %% [markdown]
# adding a total column which is the sum of all the years for a particular country

# %%
years = list(range(1980,2014))
df['total']= df[years].sum(axis=1)
df.head(3)
# Out:
#             continent           region      country_status  1980  1981  1982  \
# country
# Afghanistan      Asia    Southern Asia  Developing regions    16    39    39
# Albania        Europe  Southern Europe   Developed regions     1     0     0
# Algeria        Africa  Northern Africa  Developing regions    80    67    71
#
#              1983  1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  \
# country                              ...
# Afghanistan    47    71   340   496  ...  3436  3009  2652  2111  1746  1758
# Albania         0     0     0     1  ...  1223   856   702   560   716   561
# Algeria        69    63    44    69  ...  3626  4807  3623  4005  5393  4752
#
#              2011  2012  2013  total
# country
# Afghanistan  2203  2635  2004  58639
# Albania       539   620   603  15699
# Algeria      4325  3774  4331  69439
#
# [3 rows x 38 columns]

# %% [markdown]
# making the country status to binary

# %%
def binarize(val):
    if val =='Developing regions':
        return 0
    else:
        return 1
df['country_status']=df['country_status'].apply(binarize)

# %%
df.head()
# Out:
#                continent           region  country_status  1980  1981  1982  \
# country
# Afghanistan         Asia    Southern Asia               0    16    39    39
# Albania           Europe  Southern Europe               1     1     0     0
# Algeria           Africa  Northern Africa               0    80    67    71
# American Samoa   Oceania        Polynesia               0     0     1     0
# Andorra           Europe  Southern Europe               1     0     0     0
#
#                 1983  1984  1985  1986  ...  2005  2006  2007  2008  2009  \
# country                                 ...
# Afghanistan       47    71   340   496  ...  3436  3009  2652  2111  1746
# Albania            0     0     0     1  ...  1223   856   702   560   716
# Algeria           69    63    44    69  ...  3626  4807  3623  4005  5393
# American Samoa     0     0     0     0  ...     0     1     0     0     0
# Andorra            0     0     0     2  ...     0     1     1     0     0
#
#                 2010  2011  2012  2013  total
# country
# Afghanistan     1758  2203  2635  2004  58639
# Albania          561   539   620   603  15699
# Algeria         4752  4325  3774  4331  69439
# American Samoa     0     0     0     0      6
# Andorra            0     0     1     1     15
#
# [5 rows x 38 columns]

# %%
df.sort_values(by='total', ascending=False, inplace=True)
df.head()
# Out:
#                                                    continent  \
# country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                 region  \
# country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                     country_status   1980  \
# country
# India                                                            0   8880
# China                                                            0   5123
# United Kingdom of Great Britain and Northern Ir...               1  22045
# Philippines                                                      0   6051
# Pakistan                                                         0    978
#
#                                                      1981   1982   1983  \
# country
# India                                                8670   8147   7338
# China                                                6682   3308   1863
# United Kingdom of Great Britain and Northern Ir...  24796  20620  10015
# Philippines                                          5921   5249   4562
# Pakistan                                              972   1201    900
#
#                                                      1984  1985  1986  ...  \
# country                                                                ...
# India                                                5704  4211  7150  ...
# China                                                1527  1816  1960  ...
# United Kingdom of Great Britain and Northern Ir...  10170  9564  9470  ...
# Philippines                                          3801  3150  4166  ...
# Pakistan                                              668   514   691  ...
#
#                                                      2005   2006   2007  \
# country
# India                                               36210  33848  28742
# China                                               42584  33518  27642
# United Kingdom of Great Britain and Northern Ir...   7258   7140   8216
# Philippines                                         18139  18400  19837
# Pakistan                                            14314  13127  10124
#
#                                                      2008   2009   2010  \
# country
# India                                               28261  29456  34235
# China                                               30037  29622  30391
# United Kingdom of Great Britain and Northern Ir...   8979   8876   8724
# Philippines                                         24887  28573  38617
# Pakistan                                             8994   7217   6811
#
#                                                      2011   2012   2013  \
# country
# India                                               27509  30933  33087
# China                                               28502  33024  34129
# United Kingdom of Great Britain and Northern Ir...   6204   6195   5827
# Philippines                                         36765  34315  29544
# Pakistan                                             7468  11227  12603
#
#                                                      total
# country
# India                                               691904
# China                                               659962
# United Kingdom of Great Britain and Northern Ir...  551500
# Philippines                                         511391
# Pakistan                                            241600
#
# [5 rows x 38 columns]

# %% [markdown]
# rename few country names (that is index column)

# %%
print(df.index)

# %%
df.rename({
    
})

# %% [markdown]
# # change plotting theme

# %%
print(plt.style.available)
plt.style.use('ggplot')  #can use other than ggplot like dark_background
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df.loc['Japan', years].plot(kind='line', figsize=(20,6))
plt.show()

# %% [markdown]
# # add pandas styling

# %%
continent_df =df.groupby('continent')[years].sum()

# %%
continent_df.style.background_gradient(cmap='summer')  #cool, hot, rainbow , rainbow_r --> reverse any colour by _r,
# Out:
# <style type="text/css">
# #T_ceaa4_row0_col0, #T_ceaa4_row0_col2, #T_ceaa4_row4_col10, #T_ceaa4_row4_col29 {
#   background-color: #0d8666;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col1, #T_ceaa4_row4_col27, #T_ceaa4_row4_col28 {
#   background-color: #0f8766;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col3, #T_ceaa4_row0_col4 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col5 {
#   background-color: #138966;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col6 {
#   background-color: #1a8c66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col7, #T_ceaa4_row0_col16 {
#   background-color: #239166;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col8, #T_ceaa4_row3_col20 {
#   background-color: #1e8e66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col9, #T_ceaa4_row0_col18, #T_ceaa4_row0_col19, #T_ceaa4_row0_col20, #T_ceaa4_row3_col18, #T_ceaa4_row3_col23, #T_ceaa4_row4_col7 {
#   background-color: #249266;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col10, #T_ceaa4_row0_col14, #T_ceaa4_row0_col17 {
#   background-color: #209066;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col11 {
#   background-color: #229066;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col12, #T_ceaa4_row3_col27 {
#   background-color: #2f9766;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col13, #T_ceaa4_row3_col25 {
#   background-color: #259266;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col15, #T_ceaa4_row3_col17, #T_ceaa4_row3_col33 {
#   background-color: #269266;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col21, #T_ceaa4_row0_col22, #T_ceaa4_row3_col24 {
#   background-color: #279366;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col23, #T_ceaa4_row0_col25, #T_ceaa4_row3_col30 {
#   background-color: #2a9466;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col24, #T_ceaa4_row4_col0 {
#   background-color: #329866;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col26, #T_ceaa4_row4_col1 {
#   background-color: #309866;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col27 {
#   background-color: #339966;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col28 {
#   background-color: #349a66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col29, #T_ceaa4_row0_col31 {
#   background-color: #3b9d66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row0_col30, #T_ceaa4_row0_col32, #T_ceaa4_row0_col33, #T_ceaa4_row2_col27 {
#   background-color: #3d9e66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row1_col0 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_ceaa4_row1_col1 {
#   background-color: #c1e066;
#   color: #000000;
# }
# #T_ceaa4_row1_col2 {
#   background-color: #b1d866;
#   color: #000000;
# }
# #T_ceaa4_row1_col3, #T_ceaa4_row1_col4, #T_ceaa4_row1_col5, #T_ceaa4_row1_col6, #T_ceaa4_row1_col10, #T_ceaa4_row1_col11, #T_ceaa4_row1_col12, #T_ceaa4_row1_col13, #T_ceaa4_row1_col14, #T_ceaa4_row1_col15, #T_ceaa4_row1_col16, #T_ceaa4_row1_col17, #T_ceaa4_row1_col18, #T_ceaa4_row1_col19, #T_ceaa4_row1_col20, #T_ceaa4_row1_col21, #T_ceaa4_row1_col22, #T_ceaa4_row1_col23, #T_ceaa4_row1_col24, #T_ceaa4_row1_col25, #T_ceaa4_row1_col26, #T_ceaa4_row1_col27, #T_ceaa4_row1_col28, #T_ceaa4_row1_col29, #T_ceaa4_row1_col30, #T_ceaa4_row1_col31, #T_ceaa4_row1_col32, #T_ceaa4_row1_col33, #T_ceaa4_row2_col0, #T_ceaa4_row2_col1, #T_ceaa4_row2_col2, #T_ceaa4_row2_col3, #T_ceaa4_row2_col7, #T_ceaa4_row2_col8, #T_ceaa4_row2_col9 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_ceaa4_row1_col7 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_ceaa4_row1_col8 {
#   background-color: #ddee66;
#   color: #000000;
# }
# #T_ceaa4_row1_col9 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_ceaa4_row2_col4 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_ceaa4_row2_col5 {
#   background-color: #deee66;
#   color: #000000;
# }
# #T_ceaa4_row2_col6 {
#   background-color: #d7eb66;
#   color: #000000;
# }
# #T_ceaa4_row2_col10 {
#   background-color: #eff766;
#   color: #000000;
# }
# #T_ceaa4_row2_col11 {
#   background-color: #a2d066;
#   color: #000000;
# }
# #T_ceaa4_row2_col12, #T_ceaa4_row2_col14 {
#   background-color: #b2d866;
#   color: #000000;
# }
# #T_ceaa4_row2_col13 {
#   background-color: #a0d066;
#   color: #000000;
# }
# #T_ceaa4_row2_col15 {
#   background-color: #9cce66;
#   color: #000000;
# }
# #T_ceaa4_row2_col16 {
#   background-color: #88c366;
#   color: #000000;
# }
# #T_ceaa4_row2_col17 {
#   background-color: #73b966;
#   color: #f1f1f1;
# }
# #T_ceaa4_row2_col18, #T_ceaa4_row3_col9, #T_ceaa4_row3_col12 {
#   background-color: #65b266;
#   color: #f1f1f1;
# }
# #T_ceaa4_row2_col19, #T_ceaa4_row3_col13 {
#   background-color: #53a966;
#   color: #f1f1f1;
# }
# #T_ceaa4_row2_col20 {
#   background-color: #46a266;
#   color: #f1f1f1;
# }
# #T_ceaa4_row2_col21 {
#   background-color: #47a366;
#   color: #f1f1f1;
# }
# #T_ceaa4_row2_col22 {
#   background-color: #42a066;
#   color: #f1f1f1;
# }
# #T_ceaa4_row2_col23 {
#   background-color: #40a066;
#   color: #f1f1f1;
# }
# #T_ceaa4_row2_col24 {
#   background-color: #45a266;
#   color: #f1f1f1;
# }
# #T_ceaa4_row2_col25 {
#   background-color: #379b66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row2_col26 {
#   background-color: #369a66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row2_col28, #T_ceaa4_row2_col29 {
#   background-color: #3c9e66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row2_col30 {
#   background-color: #319866;
#   color: #f1f1f1;
# }
# #T_ceaa4_row2_col31, #T_ceaa4_row2_col33 {
#   background-color: #2c9666;
#   color: #f1f1f1;
# }
# #T_ceaa4_row2_col32, #T_ceaa4_row3_col31, #T_ceaa4_row4_col2 {
#   background-color: #2e9666;
#   color: #f1f1f1;
# }
# #T_ceaa4_row3_col0 {
#   background-color: #4ba566;
#   color: #f1f1f1;
# }
# #T_ceaa4_row3_col1 {
#   background-color: #4fa766;
#   color: #f1f1f1;
# }
# #T_ceaa4_row3_col2 {
#   background-color: #5eae66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row3_col3 {
#   background-color: #9bcd66;
#   color: #000000;
# }
# #T_ceaa4_row3_col4 {
#   background-color: #7cbe66;
#   color: #000000;
# }
# #T_ceaa4_row3_col5 {
#   background-color: #9fcf66;
#   color: #000000;
# }
# #T_ceaa4_row3_col6 {
#   background-color: #badc66;
#   color: #000000;
# }
# #T_ceaa4_row3_col7 {
#   background-color: #99cc66;
#   color: #000000;
# }
# #T_ceaa4_row3_col8 {
#   background-color: #63b166;
#   color: #f1f1f1;
# }
# #T_ceaa4_row3_col10 {
#   background-color: #5dae66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row3_col11 {
#   background-color: #64b266;
#   color: #f1f1f1;
# }
# #T_ceaa4_row3_col14 {
#   background-color: #399c66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row3_col15 {
#   background-color: #359a66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row3_col16, #T_ceaa4_row3_col32 {
#   background-color: #2b9566;
#   color: #f1f1f1;
# }
# #T_ceaa4_row3_col19, #T_ceaa4_row3_col22 {
#   background-color: #219066;
#   color: #f1f1f1;
# }
# #T_ceaa4_row3_col21 {
#   background-color: #1f8f66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row3_col26 {
#   background-color: #289366;
#   color: #f1f1f1;
# }
# #T_ceaa4_row3_col28, #T_ceaa4_row3_col29 {
#   background-color: #2d9666;
#   color: #f1f1f1;
# }
# #T_ceaa4_row4_col3 {
#   background-color: #41a066;
#   color: #f1f1f1;
# }
# #T_ceaa4_row4_col4, #T_ceaa4_row4_col6 {
#   background-color: #389c66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row4_col5 {
#   background-color: #3e9e66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row4_col8 {
#   background-color: #198c66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row4_col9 {
#   background-color: #168a66;
#   color: #f1f1f1;
# }
# #T_ceaa4_row4_col11, #T_ceaa4_row4_col16, #T_ceaa4_row4_col19, #T_ceaa4_row4_col24, #T_ceaa4_row4_col31, #T_ceaa4_row4_col32 {
#   background-color: #0a8466;
#   color: #f1f1f1;
# }
# #T_ceaa4_row4_col12, #T_ceaa4_row4_col14, #T_ceaa4_row4_col25, #T_ceaa4_row4_col33 {
#   background-color: #0b8566;
#   color: #f1f1f1;
# }
# #T_ceaa4_row4_col13 {
#   background-color: #0c8666;
#   color: #f1f1f1;
# }
# #T_ceaa4_row4_col15, #T_ceaa4_row4_col18, #T_ceaa4_row4_col30 {
#   background-color: #098466;
#   color: #f1f1f1;
# }
# #T_ceaa4_row4_col17 {
#   background-color: #088466;
#   color: #f1f1f1;
# }
# #T_ceaa4_row4_col20, #T_ceaa4_row4_col23 {
#   background-color: #078366;
#   color: #f1f1f1;
# }
# #T_ceaa4_row4_col21, #T_ceaa4_row4_col22 {
#   background-color: #068266;
#   color: #f1f1f1;
# }
# #T_ceaa4_row4_col26 {
#   background-color: #0e8666;
#   color: #f1f1f1;
# }
# #T_ceaa4_row5_col0, #T_ceaa4_row5_col1, #T_ceaa4_row5_col2, #T_ceaa4_row5_col3, #T_ceaa4_row5_col4, #T_ceaa4_row5_col5, #T_ceaa4_row5_col6, #T_ceaa4_row5_col7, #T_ceaa4_row5_col8, #T_ceaa4_row5_col9, #T_ceaa4_row5_col10, #T_ceaa4_row5_col11, #T_ceaa4_row5_col12, #T_ceaa4_row5_col13, #T_ceaa4_row5_col14, #T_ceaa4_row5_col15, #T_ceaa4_row5_col16, #T_ceaa4_

# %%
continent_df.style.bar(color='darkblue')
# Out:
# <style type="text/css">
# #T_dc508_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 9.9%, transparent 9.9%);
# }
# #T_dc508_row0_col1, #T_dc508_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 9.7%, transparent 9.7%);
# }
# #T_dc508_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 8.9%, transparent 8.9%);
# }
# #T_dc508_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 10.8%, transparent 10.8%);
# }
# #T_dc508_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 11.1%, transparent 11.1%);
# }
# #T_dc508_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 13.2%, transparent 13.2%);
# }
# #T_dc508_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 16.0%, transparent 16.0%);
# }
# #T_dc508_row0_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 13.8%, transparent 13.8%);
# }
# #T_dc508_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 16.2%, transparent 16.2%);
# }
# #T_dc508_row0_col10, #T_dc508_row0_col20 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 15.1%, transparent 15.1%);
# }
# #T_dc508_row0_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 15.8%, transparent 15.8%);
# }
# #T_dc508_row0_col12, #T_dc508_row0_col27, #T_dc508_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 21.2%, transparent 21.2%);
# }
# #T_dc508_row0_col13 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 16.7%, transparent 16.7%);
# }
# #T_dc508_row0_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 14.7%, transparent 14.7%);
# }
# #T_dc508_row0_col15, #T_dc508_row0_col21, #T_dc508_row3_col24 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 16.4%, transparent 16.4%);
# }
# #T_dc508_row0_col16, #T_dc508_row0_col18, #T_dc508_row3_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 15.2%, transparent 15.2%);
# }
# #T_dc508_row0_col17, #T_dc508_row3_col21 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 13.6%, transparent 13.6%);
# }
# #T_dc508_row0_col19 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 15.0%, transparent 15.0%);
# }
# #T_dc508_row0_col22, #T_dc508_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 16.5%, transparent 16.5%);
# }
# #T_dc508_row0_col23 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 17.7%, transparent 17.7%);
# }
# #T_dc508_row0_col24 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 20.9%, transparent 20.9%);
# }
# #T_dc508_row0_col25 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 17.3%, transparent 17.3%);
# }
# #T_dc508_row0_col26 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 19.6%, transparent 19.6%);
# }
# #T_dc508_row0_col28 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 21.4%, transparent 21.4%);
# }
# #T_dc508_row0_col29, #T_dc508_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 24.4%, transparent 24.4%);
# }
# #T_dc508_row0_col30, #T_dc508_row0_col32 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 25.0%, transparent 25.0%);
# }
# #T_dc508_row0_col31 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 24.1%, transparent 24.1%);
# }
# #T_dc508_row0_col33 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 24.9%, transparent 24.9%);
# }
# #T_dc508_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 78.0%, transparent 78.0%);
# }
# #T_dc508_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 76.6%, transparent 76.6%);
# }
# #T_dc508_row1_col2, #T_dc508_row2_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 70.7%, transparent 70.7%);
# }
# #T_dc508_row1_col3, #T_dc508_row1_col4, #T_dc508_row1_col5, #T_dc508_row1_col6, #T_dc508_row1_col10, #T_dc508_row1_col11, #T_dc508_row1_col12, #T_dc508_row1_col13, #T_dc508_row1_col14, #T_dc508_row1_col15, #T_dc508_row1_col16, #T_dc508_row1_col17, #T_dc508_row1_col18, #T_dc508_row1_col19, #T_dc508_row1_col20, #T_dc508_row1_col21, #T_dc508_row1_col22, #T_dc508_row1_col23, #T_dc508_row1_col24, #T_dc508_row1_col25, #T_dc508_row1_col26, #T_dc508_row1_col27, #T_dc508_row1_col28, #T_dc508_row1_col29, #T_dc508_row1_col30, #T_dc508_row1_col31, #T_dc508_row1_col32, #T_dc508_row1_col33, #T_dc508_row2_col0, #T_dc508_row2_col1, #T_dc508_row2_col2, #T_dc508_row2_col7, #T_dc508_row2_col8, #T_dc508_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 100.0%, transparent 100.0%);
# }
# #T_dc508_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 92.5%, transparent 92.5%);
# }
# #T_dc508_row1_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 86.7%, transparent 86.7%);
# }
# #T_dc508_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 99.0%, transparent 99.0%);
# }
# #T_dc508_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 99.8%, transparent 99.8%);
# }
# #T_dc508_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 81.7%, transparent 81.7%);
# }
# #T_dc508_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 87.4%, transparent 87.4%);
# }
# #T_dc508_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 84.8%, transparent 84.8%);
# }
# #T_dc508_row2_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 93.8%, transparent 93.8%);
# }
# #T_dc508_row2_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 64.4%, transparent 64.4%);
# }
# #T_dc508_row2_col13 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 63.7%, transparent 63.7%);
# }
# #T_dc508_row2_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 70.4%, transparent 70.4%);
# }
# #T_dc508_row2_col15 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 61.7%, transparent 61.7%);
# }
# #T_dc508_row2_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 54.0%, transparent 54.0%);
# }
# #T_dc508_row2_col17 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 45.9%, transparent 45.9%);
# }
# #T_dc508_row2_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 40.4%, transparent 40.4%);
# }
# #T_dc508_row2_col19 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 33.4%, transparent 33.4%);
# }
# #T_dc508_row2_col20 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 28.4%, transparent 28.4%);
# }
# #T_dc508_row2_col21 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 28.9%, transparent 28.9%);
# }
# #T_dc508_row2_col22 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 26.7%, transparent 26.7%);
# }
# #T_dc508_row2_col23 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 26.2%, transparent 26.2%);
# }
# #T_dc508_row2_col24 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 28.2%, transparent 28.2%);
# }
# #T_dc508_row2_col25 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 22.6%, transparent 22.6%);
# }
# #T_dc508_row2_col26 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 22.2%, transparent 22.2%);
# }
# #T_dc508_row2_col27 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 25.1%, transparent 25.1%);
# }
# #T_dc508_row2_col28, #T_dc508_row2_col29 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 24.8%, transparent 24.8%);
# }
# #T_dc508_row2_col30 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 20.4%, transparent 20.4%);
# }
# #T_dc508_row2_col31 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 18.2%, transparent 18.2%);
# }
# #T_dc508_row2_col32 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 19.2%, transparent 19.2%);
# }
# #T_dc508_row2_col33 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 18.5%, transparent 18.5%);
# }
# #T_dc508_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 32.9%, transparent 32.9%);
# }
# #T_dc508_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, darkblue 3

# %%
continent_df.style.text_gradient(cmap='rainbow')  # styling unnecessarily takes a lot of memory
# Out:
# <style type="text/css">
# #T_9bddf_row0_col0, #T_9bddf_row0_col2, #T_9bddf_row4_col10, #T_9bddf_row4_col29 {
#   color: #6629fe;
# }
# #T_9bddf_row0_col1, #T_9bddf_row4_col27, #T_9bddf_row4_col28 {
#   color: #622ffe;
# }
# #T_9bddf_row0_col3, #T_9bddf_row0_col4 {
#   color: #5e35fe;
# }
# #T_9bddf_row0_col5 {
#   color: #5a3bfd;
# }
# #T_9bddf_row0_col6 {
#   color: #4c50fc;
# }
# #T_9bddf_row0_col7, #T_9bddf_row0_col16 {
#   color: #396bf9;
# }
# #T_9bddf_row0_col8, #T_9bddf_row3_col20 {
#   color: #445cfb;
# }
# #T_9bddf_row0_col9, #T_9bddf_row0_col18, #T_9bddf_row0_col19, #T_9bddf_row0_col20, #T_9bddf_row3_col18, #T_9bddf_row3_col23, #T_9bddf_row4_col7 {
#   color: #386df9;
# }
# #T_9bddf_row0_col10, #T_9bddf_row0_col14, #T_9bddf_row0_col17 {
#   color: #4062fa;
# }
# #T_9bddf_row0_col11 {
#   color: #3c68f9;
# }
# #T_9bddf_row0_col12, #T_9bddf_row3_col27 {
#   color: #218cf4;
# }
# #T_9bddf_row0_col13, #T_9bddf_row3_col25 {
#   color: #3670f8;
# }
# #T_9bddf_row0_col15, #T_9bddf_row3_col17, #T_9bddf_row3_col33 {
#   color: #3473f8;
# }
# #T_9bddf_row0_col21, #T_9bddf_row0_col22, #T_9bddf_row3_col24 {
#   color: #3176f8;
# }
# #T_9bddf_row0_col23, #T_9bddf_row0_col25, #T_9bddf_row3_col30 {
#   color: #2c7ef7;
# }
# #T_9bddf_row0_col24, #T_9bddf_row4_col0 {
#   color: #1c93f3;
# }
# #T_9bddf_row0_col26, #T_9bddf_row4_col1 {
#   color: #208ef4;
# }
# #T_9bddf_row0_col27 {
#   color: #1996f3;
# }
# #T_9bddf_row0_col28 {
#   color: #1898f2;
# }
# #T_9bddf_row0_col29, #T_9bddf_row0_col31 {
#   color: #09a9ee;
# }
# #T_9bddf_row0_col30, #T_9bddf_row0_col32, #T_9bddf_row0_col33, #T_9bddf_row2_col27 {
#   color: #06aeed;
# }
# #T_9bddf_row1_col0 {
#   color: #ffa95b;
# }
# #T_9bddf_row1_col1 {
#   color: #ffb05f;
# }
# #T_9bddf_row1_col2 {
#   color: #e2d176;
# }
# #T_9bddf_row1_col3, #T_9bddf_row1_col4, #T_9bddf_row1_col5, #T_9bddf_row1_col6, #T_9bddf_row1_col10, #T_9bddf_row1_col11, #T_9bddf_row1_col12, #T_9bddf_row1_col13, #T_9bddf_row1_col14, #T_9bddf_row1_col15, #T_9bddf_row1_col16, #T_9bddf_row1_col17, #T_9bddf_row1_col18, #T_9bddf_row1_col19, #T_9bddf_row1_col20, #T_9bddf_row1_col21, #T_9bddf_row1_col22, #T_9bddf_row1_col23, #T_9bddf_row1_col24, #T_9bddf_row1_col25, #T_9bddf_row1_col26, #T_9bddf_row1_col27, #T_9bddf_row1_col28, #T_9bddf_row1_col29, #T_9bddf_row1_col30, #T_9bddf_row1_col31, #T_9bddf_row1_col32, #T_9bddf_row1_col33, #T_9bddf_row2_col0, #T_9bddf_row2_col1, #T_9bddf_row2_col2, #T_9bddf_row2_col3, #T_9bddf_row2_col7, #T_9bddf_row2_col8, #T_9bddf_row2_col9 {
#   color: #ff0000;
# }
# #T_9bddf_row1_col7 {
#   color: #ff3b1e;
# }
# #T_9bddf_row1_col8 {
#   color: #ff6835;
# }
# #T_9bddf_row1_col9 {
#   color: #ff0603;
# }
# #T_9bddf_row2_col4 {
#   color: #ff8e4a;
# }
# #T_9bddf_row2_col5 {
#   color: #ff6533;
# }
# #T_9bddf_row2_col6 {
#   color: #ff793e;
# }
# #T_9bddf_row2_col10 {
#   color: #ff3219;
# }
# #T_9bddf_row2_col11 {
#   color: #c4e88a;
# }
# #T_9bddf_row2_col12, #T_9bddf_row2_col14 {
#   color: #e4cf74;
# }
# #T_9bddf_row2_col13 {
#   color: #c0eb8d;
# }
# #T_9bddf_row2_col15 {
#   color: #b9ef92;
# }
# #T_9bddf_row2_col16 {
#   color: #90feab;
# }
# #T_9bddf_row2_col17 {
#   color: #66fcc2;
# }
# #T_9bddf_row2_col18, #T_9bddf_row3_col9, #T_9bddf_row3_col12 {
#   color: #4af2cf;
# }
# #T_9bddf_row2_col19, #T_9bddf_row3_col13 {
#   color: #27dade;
# }
# #T_9bddf_row2_col20 {
#   color: #0dc2e8;
# }
# #T_9bddf_row2_col21 {
#   color: #0fc4e7;
# }
# #T_9bddf_row2_col22 {
#   color: #04b9ea;
# }
# #T_9bddf_row2_col23 {
#   color: #00b5eb;
# }
# #T_9bddf_row2_col24 {
#   color: #0ac0e8;
# }
# #T_9bddf_row2_col25 {
#   color: #11a0f1;
# }
# #T_9bddf_row2_col26 {
#   color: #149df1;
# }
# #T_9bddf_row2_col28, #T_9bddf_row2_col29 {
#   color: #08acee;
# }
# #T_9bddf_row2_col30 {
#   color: #1e91f3;
# }
# #T_9bddf_row2_col31, #T_9bddf_row2_col33 {
#   color: #2884f6;
# }
# #T_9bddf_row2_col32, #T_9bddf_row3_col31, #T_9bddf_row4_col2 {
#   color: #2489f5;
# }
# #T_9bddf_row3_col0 {
#   color: #17cbe4;
# }
# #T_9bddf_row3_col1 {
#   color: #1fd3e1;
# }
# #T_9bddf_row3_col2 {
#   color: #3dead5;
# }
# #T_9bddf_row3_col3 {
#   color: #b6f193;
# }
# #T_9bddf_row3_col4 {
#   color: #78ffb8;
# }
# #T_9bddf_row3_col5 {
#   color: #beec8e;
# }
# #T_9bddf_row3_col6 {
#   color: #f4c069;
# }
# #T_9bddf_row3_col7 {
#   color: #b2f396;
# }
# #T_9bddf_row3_col8 {
#   color: #46efd1;
# }
# #T_9bddf_row3_col10 {
#   color: #3ae8d6;
# }
# #T_9bddf_row3_col11 {
#   color: #48f1d0;
# }
# #T_9bddf_row3_col14 {
#   color: #0ea5ef;
# }
# #T_9bddf_row3_col15 {
#   color: #169bf2;
# }
# #T_9bddf_row3_col16, #T_9bddf_row3_col32 {
#   color: #2981f6;
# }
# #T_9bddf_row3_col19, #T_9bddf_row3_col22 {
#   color: #3e65fa;
# }
# #T_9bddf_row3_col21 {
#   color: #425ffa;
# }
# #T_9bddf_row3_col26 {
#   color: #3079f7;
# }
# #T_9bddf_row3_col28, #T_9bddf_row3_col29 {
#   color: #2686f5;
# }
# #T_9bddf_row4_col3 {
#   color: #02b7eb;
# }
# #T_9bddf_row4_col4, #T_9bddf_row4_col6 {
#   color: #10a2f0;
# }
# #T_9bddf_row4_col5 {
#   color: #04b0ed;
# }
# #T_9bddf_row4_col8 {
#   color: #4e4dfc;
# }
# #T_9bddf_row4_col9 {
#   color: #5444fd;
# }
# #T_9bddf_row4_col11, #T_9bddf_row4_col16, #T_9bddf_row4_col19, #T_9bddf_row4_col24, #T_9bddf_row4_col31, #T_9bddf_row4_col32 {
#   color: #6c1fff;
# }
# #T_9bddf_row4_col12, #T_9bddf_row4_col14, #T_9bddf_row4_col25, #T_9bddf_row4_col33 {
#   color: #6a22fe;
# }
# #T_9bddf_row4_col13 {
#   color: #6826fe;
# }
# #T_9bddf_row4_col15, #T_9bddf_row4_col18, #T_9bddf_row4_col30 {
#   color: #6e1cff;
# }
# #T_9bddf_row4_col17 {
#   color: #7019ff;
# }
# #T_9bddf_row4_col20, #T_9bddf_row4_col23 {
#   color: #7216ff;
# }
# #T_9bddf_row4_col21, #T_9bddf_row4_col22 {
#   color: #7413ff;
# }
# #T_9bddf_row4_col26 {
#   color: #642cfe;
# }
# #T_9bddf_row5_col0, #T_9bddf_row5_col1, #T_9bddf_row5_col2, #T_9bddf_row5_col3, #T_9bddf_row5_col4, #T_9bddf_row5_col5, #T_9bddf_row5_col6, #T_9bddf_row5_col7, #T_9bddf_row5_col8, #T_9bddf_row5_col9, #T_9bddf_row5_col10, #T_9bddf_row5_col11, #T_9bddf_row5_col12, #T_9bddf_row5_col13, #T_9bddf_row5_col14, #T_9bddf_row5_col15, #T_9bddf_row5_col16, #T_9bddf_row5_col17, #T_9bddf_row5_col18, #T_9bddf_row5_col19, #T_9bddf_row5_col20, #T_9bddf_row5_col21, #T_9bddf_row5_col22, #T_9bddf_row5_col23, #T_9bddf_row5_col24, #T_9bddf_row5_col25, #T_9bddf_row5_col26, #T_9bddf_row5_col27, #T_9bddf_row5_col28, #T_9bddf_row5_col29, #T_9bddf_row5_col30, #T_9bddf_row5_col31, #T_9bddf_row5_col32, #T_9bddf_row5_col33 {
#   color: #8000ff;
# }
# </style>
# <table id="T_9bddf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bddf_level0_col0" class="col_heading level0 col0" >1980</th>
#       <th id="T_9bddf_level0_col1" class="col_heading level0 col1" >1981</th>
#       <th id="T_9bddf_level0_col2" class="col_heading level0 col2" >1982</th>
#       <th id="T_9bddf_level0_col3" class="col_heading level0 col3" >1983</th>
#       <th id="T_9bddf_level0_col4" class="col_heading level0 col4" >1984</th>
#       <th id="T_9bddf_level0_col5" class="col_heading level0 col5" >1985</th>
#       <th id="T_9bddf_level0_col6" class="col_heading level0 col6" >1986</th>
#       <th id="T_9bddf_level0_col7" class="col_heading level0 col7" >1987</th>
#       <th id="T_9bddf_level0_col8" class="col_heading level0 col8" >1988</th>
#       <th id="T_9bddf_level0_col9" class="col_heading level0 col9" >1989</th>
#       <th id="T_9bddf_level0_col10" class="col_heading level0 col10" >1990</th>
#       <th id="T_9bddf_level0_col11" class="col_heading level0 col11" >1991</th>
#       <th id="T_9bddf_level0_col12" class="col_heading level0 col12" >1992</th>
#       <th id="T_9bddf_level0_col13" class="col_heading level0 col13" >1993</th>
#       <th id="T_9bddf_level0_col14" class="col_heading level0 col14" >1994</th>
#       <th id="T_9bddf_level0_col15" class="col_heading level0 col15" >1995</th>
#       <th id="T_9bddf_level0_col16" class="col_heading level0 col16" >1996</th>
#       <th id="T_9bddf_level0_col17" class="col_heading level0 col17" >1997</th>
#       <th id="T_9bddf_level0_col18" class="col_heading level0 col18" >1998</th>
#       <th id="T_9bddf_level0_col19" class="col_heading level0 col19" >1999</th>
#       <th id="T_9bddf_level0_col20" class="col_heading level0 col20" >2000</th>
#       <th id="T_9bddf_level0_col21" class="col_heading level0 col21" >2001</th>
#       <th id="T_9bddf_level0_col22" class="col_heading level0 col22" >2002</th>
#       <th id="T_9bddf_level0_col23" class="col_heading level0 col23" >2003</th>
#       <th id="T_

# %% [markdown]
# # visualisation
